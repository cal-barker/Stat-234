# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import csv

# %%
# URL
url = "https://och.byu.edu/all-facilities"
html = urlopen(url)
soup = BeautifulSoup(html)

df = pd.DataFrame(columns = ['value'])

# %%
soup
#soup.findAll('tr', limit=2)
results = soup.findAll('td', class_='line1')


for i in range(0, len(results)):
    string = str(results[i])
    string = string.replace('"', "").replace("<td class=line1>", "").replace("</td>","")
    df = df.append({'value' : string}, ignore_index = True)
#df.head()

# %%
searchfor = [' N ', ' S ', ' E ', ' W', '\n', 'hide', 'Large', 'Small', 'Medium', 'Condominium']
df= df[df["value"].str.contains('|'.join(searchfor)) == False]

# %%
df_true = df[df['value'] != ""]
df_true = df_true.drop_duplicates()

# %%
df_true.to_csv("~/Desktop/housing.csv")

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #maincontent
# https://byu.edu
# https://och.byu.edu/
# https://home.byu.edu/och/welcome.htm
# https://och.byu.edu/
# https://och.byu.edu/students
# https://och.byu.edu/landlord-resources
# https://och.byu.edu/faq
# https://och.byu.edu/contact
# https://housing.byu.edu/secure/services/c_guidlines_single/ResidentialLivingStandards.aspx
# https://och.byu.edu/all-facilities
# https://och.byu.edu/all-facilities
# https://och.byu.edu/large-facilities
# https://och.byu.edu/medium-facilities
# https://och.byu.edu/small-facilities
# https://och.byu.edu/condominiums
# mailto:och@byu.edu
# https://enrollment2.byu.edu/academic-calendar
# https://uac.byu.edu/
# https://cpcr.byu.edu/
# https://honorcode.byu.edu/
# https://housing.byu.edu/secure/services/c_main/default.aspx
# http://och.byu.edu/contact.html
# https://housing.byu.edu/secure/services/c_main/default.aspx
# https://www.instagram.com/brighamyounguniversity/
# https://twitter.com/byu
# https://www.youtube.com/user/BYUNews
# ...
